# %% [markdown]
# # **Project Name**    -  Yes Bank Stock Price Analysis

# %% [markdown]
# ## **Project Type**    - EDA - Unsupervised
# ## **Contribution**    - Individual
# ## **Team Member 1 -** - Veerendra Kashyap

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on a comprehensive exploratory data analysis (EDA) of Yes Bank's historical stock price data. The aim is to uncover patterns, assess risk factors, and understand the bank's market performance through detailed data exploration and financial metrics. Let’s break down the findings and key insights.
#
# #### Data Understanding and Preparation
# The dataset includes essential stock attributes such as:
# - **Date**
# - **Open Price**
# - **High Price**
# - **Low Price**
# - **Close Price**
# - **Trading Volume**
#
# Proper preprocessing steps were applied, including handling date formats, checking for missing values, and treating outliers. This ensures that the data remains clean, accurate, and ready for analysis.
#
# #### Trend and Pattern Analysis
# By exploring the time series data, we identified:
# - **Upward and downward price trends** over different time periods.
# - Periods of **rapid growth and sharp declines**, which correlate with broader market events or company-specific factors.
#
# Understanding these patterns helps investors anticipate future price movements and build informed trading strategies.
#
# #### Volatility and Risk Assessment
# Volatility is a key metric in stock trading. We assessed historical volatility to understand price fluctuations:
# - **High volatility periods** often align with significant events or external market pressures.
# - Investors can use volatility insights to manage risk, avoiding trades during highly uncertain periods.
#
# This helps traders balance potential returns against the risk of unpredictable price swings.
#
# #### Return Analysis and Investment Insights
# Return analysis offers valuable information for investors:
# - **Daily returns** provide insight into short-term performance.
# - **Cumulative returns** show how an investment grows over time.
#
# These metrics help investors measure profitability and decide whether a stock aligns with their financial goals.
#
# #### Correlation and Dependency
# We examined the correlation between stock price components (Open, High, Low, Close):
# - Strong **positive correlations** suggest that price components move in sync.
# - Understanding these relationships helps traders develop strategies based on historical price action.
#
# #### Market Sentiment and External Factors
# Stock prices are not only influenced by internal metrics but also by external factors:
# - **Interest rates** and **government policies**
# - **Global market conditions** and **industry news**
#
# Recognizing these factors helps place stock movements within a larger financial ecosystem.
#
# #### Actionable Insights
# Key takeaways for investors include:
# - **Trend-following strategies:** Use moving averages to guide entry/exit points.
# - **Risk management:** Monitor volatility to avoid uncertain periods.
# - **Seasonal patterns:** Leverage cyclical price trends for strategic trades.
#
# #### Conclusion
# This project illustrates how exploratory data analysis can transform raw stock data into actionable insights. By understanding trends, volatility, returns, and external influences, investors can make more informed decisions. The analysis not only enhances trading strategies but also highlights the value of data analytics in financial markets.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/veerendrakashyap/Yes-Bank-Stock-Price-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Yes Bank's stock prices fluctuate due to market trends, investor sentiment, and economic factors. Analyzing historical stock data is essential to uncover patterns, measure volatility, and understand price dynamics, enabling investors to make strategic decisions backed by data.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **The objective is to perform a thorough analysis of Yes Bank's stock price data through visualizations and statistical metrics to identify trends, assess risk, evaluate returns, and deliver actionable insights that help investors optimize their trading strategies and manage market uncertainties.**

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.dates import DateFormatter

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

csv_file_path = "Stock_Price.csv"
df = pd.read_csv(csv_file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

print("First 5 rows of the dataset:")
print(df.head())
# Out:
# First 5 rows of the dataset:
#      Date   Open   High    Low  Close
# 0  Jul-05  13.00  14.00  11.25  12.46
# 1  Aug-05  12.58  14.88  12.55  13.42
# 2  Sep-05  13.48  14.87  12.27  13.30
# 3  Oct-05  13.20  14.47  12.40  12.99
# 4  Nov-05  13.35  13.88  12.88  13.41

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

rows, cols = df.shape
print(f"\nNumber of Rows: {rows}, Number of Columns: {cols}")
# Out:
# Number of Rows: 185, Number of Columns: 5

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

print("\nDataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    185 non-null    object
#  1   Open    185 non-null    float64
#  2   High    185 non-null    float64
#  3   Low     185 non-null    float64
#  4   Close   185 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 7.4+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

duplicate_count = df.duplicated().sum()
print(f"\nNumber of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

missing_values = df.isnull().sum()
print("\nMissing Values Count:")
print(missing_values)
# Out:
# Missing Values Count:
# Date     0
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %%
# Visualizing the missing values

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains monthly historical stock prices of Yes Bank, with attributes like open, high, low, close prices, and volume. After handling duplicates and missing values, the data is clean and ready for analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

print("\nDataset Columns:")
print(df.columns)
# Out:
# Dataset Columns:
# Index(['Date', 'Open', 'High', 'Low', 'Close'], dtype='object')

# %%
# Dataset Describe

print("\nDataset Description:")
print(df.describe())
# Out:
# Dataset Description:
#              Open        High         Low       Close
# count  185.000000  185.000000  185.000000  185.000000
# mean   105.541405  116.104324   94.947838  105.204703
# std     98.879850  106.333497   91.219415   98.583153
# min     10.000000   11.240000    5.550000    9.980000
# 25%     33.800000   36.140000   28.510000   33.450000
# 50%     62.980000   72.550000   58.000000   62.540000
# 75%    153.000000  169.190000  138.350000  153.300000
# max    369.950000  404.000000  345.500000  367.900000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset includes key stock price variables:
#
# - Date: The month and year of the stock price.
#
# - Open: Price at market opening.
#
# - High/Low: The highest and lowest prices in the month.
#
# - Close: Price at market close.
#
# - Volume: Number of shares traded.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

print("\nUnique Values in Each Column:")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Unique Values in Each Column:
# Date: 185 unique values
# Open: 183 unique values
# High: 184 unique values
# Low: 183 unique values
# Close: 185 unique values

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Convert date to datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%b-%y')

# Drop missing values
df.dropna(inplace=True)

# Add daily returns
df['Daily_Return'] = df['Close'].pct_change()

# Sort by date
df = df.sort_values('Date')

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# We cleaned the dataset by removing null values and adding a new column for daily returns. Sorting the data chronologically enables time-series analysis, revealing price trends and market cycles.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'], color='blue')
plt.title('Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is ideal for visualizing stock price trends over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows fluctuating trends, helping identify long-term price movements.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding price trends helps investors decide the best entry and exit points.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

plt.figure(figsize=(12, 6))
plt.fill_between(df['Date'], df['High'], df['Low'], color='gray', alpha=0.3)
plt.plot(df['Date'], df['High'], color='green', label='High Price')
plt.plot(df['Date'], df['Low'], color='red', label='Low Price')
plt.title('High vs Low Price Range')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It shows price volatility and the range between high and low prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Wide ranges indicate higher volatility, signaling potential trading opportunities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding volatility helps traders manage risk.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

df['50_MA'] = df['Close'].rolling(window=50).mean()
df['200_MA'] = df['Close'].rolling(window=200).mean()
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'], label='Close Price')
plt.plot(df['Date'], df['50_MA'], label='50-Day MA')
plt.plot(df['Date'], df['200_MA'], label='200-Day MA')
plt.title('Moving Averages (50 & 200 Days)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Moving averages help smooth price trends and identify signals.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Crossovers between short and long averages suggest potential buy/sell signals.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this is crucial for technical analysis strategies.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

df['Volatility'] = df['High'] - df['Low']
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Volatility'], color='red')
plt.title('Volatility Over Time')
plt.xlabel('Date')
plt.ylabel('Price Difference')
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It directly visualizes stock price volatility.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Volatility spikes can indicate market uncertainty or news events.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding volatility helps investors decide when to trade or hold.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

window_length = 14
delta = df['Close'].diff()
up, down = delta.clip(lower=0), -delta.clip(upper=0)
roll_up = up.rolling(window=window_length).mean()
roll_down = down.rolling(window=window_length).mean()
RS = roll_up / roll_down
RSI = 100 - (100 / (1 + RS))

plt.figure(figsize=(12, 6))
plt.plot(df['Date'], RSI, color='purple')
plt.title('Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('RSI')
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# RSI measures momentum and identifies overbought/oversold conditions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# RSI > 70 suggests overbought, while RSI < 30 indicates oversold conditions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this helps traders make better buy/sell decisions.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

df['Daily_Return'] = df['Close'].pct_change()
df['Cumulative_Return'] = (1 + df['Daily_Return']).cumprod()

plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Cumulative_Return'], color='green')
plt.title('Cumulative Returns Over Time')
plt.xlabel('Date')
plt.ylabel('Cumulative Returns')
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Cumulative returns show the overall growth of an investment.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows periods of high returns and steep declines, reflecting long-term risk and reward.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes! It helps long-term investors assess growth potential and manage their strategies.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

monthly_change = df['Close'].diff()
plt.figure(figsize=(12, 6))
plt.bar(df['Date'], monthly_change, color='blue')
plt.title('Monthly Price Change')
plt.xlabel('Date')
plt.ylabel('Price Change')
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart makes it easy to visualize monthly price fluctuations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows irregular price movements, with sudden spikes and drops. This indicates potential market reactions to events or news.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, traders can use this insight to understand market cycles and plan trades during stable periods or capitalize on volatility.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

correlation_matrix = df[['Open', 'High', 'Low', 'Close']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Stock Prices')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap visually highlights the strength of relationships between variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There are strong positive correlations between open, high, low, and close prices. This makes sense, as these values naturally move together.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Absolutely! Understanding these correlations helps analysts build more accurate predictive models and refine trading strategies.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['close'], color='blue')
plt.title('Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.grid()
plt.xticks(rotation=45)  # Rotate date labels
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # Format dates as Year-Month
plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())  # Auto-adjust date intervals
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Trading volume indicates investor activity and market interest.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Volume surges often align with major price movements, signaling strong market sentiment.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes! High volume combined with price action can confirm breakouts or reversals, helping traders validate their strategies.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

rolling_mean = df['close'].rolling(window=20).mean()
rolling_std = df['close'].rolling(window=20).std()
upper_band = rolling_mean + (rolling_std * 2)
lower_band = rolling_mean - (rolling_std * 2)
plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['close'], label='Close Price', color='blue')
plt.plot(df['date'], rolling_mean, label='20-Day SMA', color='orange')
plt.fill_between(df['date'], lower_band, upper_band, color='gray', alpha=0.3)
plt.title('Bollinger Bands')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.AutoDateLocator())
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bollinger Bands help detect overbought and oversold conditions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# When prices touch the upper band, the stock may be overbought, while hitting the lower band suggests an oversold state.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, traders can use Bollinger Bands to time their trades, avoiding false signals and increasing profitability.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

plt.figure(figsize=(12, 6))
plt.hist(df['close'], bins=30, color='purple', edgecolor='black')
plt.title('Closing Price Distribution')
plt.xlabel('Closing Price')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The moving average chart is chosen to smooth out short-term price fluctuations and highlight long-term trends. It helps identify the overall direction of the market, which is essential for traders and analysts to make informed decisions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how the stock price fluctuates around the moving average. When prices consistently stay above the moving average, it indicates an uptrend, whereas prices below the average suggest a downtrend. This makes it easier to spot trend reversals.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes! The moving average helps investors make informed decisions about when to enter or exit trades, optimizing profit potential. By timing trades with trend shifts, businesses and investors can maximize returns while minimizing risk.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

plt.figure(figsize=(12, 6))
plt.scatter(df['open'], df['close'], color='red', alpha=0.5)
plt.title('Opening Price vs Closing Price')
plt.xlabel('Opening Price')
plt.ylabel('Closing Price')
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Tracking daily price changes helps understand volatility, showing how much a stock's price varies day-to-day. It’s useful for risk management and strategic planning.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals periods of high and low volatility. High volatility suggests market uncertainty, while stable periods indicate consistent price behavior.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Absolutely! Understanding volatility helps businesses adjust strategies, such as when to release market-sensitive news or when to buy/sell assets, leveraging periods of stability for steady growth.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['close'], color='green') 
plt.title('Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.xticks(rotation=45)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))  
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Volume data shows the number of shares traded, reflecting market interest. High volume during price movements validates trends, while low volume suggests weak market sentiment.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Spikes in volume often precede price breakouts or breakdowns. Rising volume during uptrends confirms buying interest, signaling bullish sentiment

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes! High-volume periods present opportunities for strategic trades. Businesses can use volume data to time stock offerings or acquisitions, aligning with market momentum to achieve favorable valuations.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

plt.figure(figsize=(12, 6))
plt.scatter(df['close'], df['high'], color='blue', alpha=0.5)  # Swapped 'volume' for 'close'
plt.title('Closing Price vs High Price')
plt.xlabel('Closing Price')
plt.ylabel('High Price')
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bollinger Bands show price volatility and potential overbought or oversold conditions. They help gauge whether prices are relatively high or low compared to recent trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Prices touching the upper band may signal overbought conditions, while the lower band suggests oversold levels. A squeeze (narrowing bands) indicates low volatility and often precedes significant price movements.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Definitely! Businesses can leverage Bollinger Band insights for optimal trade timing. For example, buying during oversold conditions or selling during overbought peaks enhances profitability.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Chart - 15 visualization code 

plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['close'], color='purple')
plt.title('Closing Price Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
step = max(1, len(df['date']) // 10)  
plt.xticks(df['date'][::step], rotation=45, ha='right')
plt.tight_layout() 
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Cumulative returns show the overall performance of an asset over time, helping assess long-term value creation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart highlights periods of strong growth or decline, showing how much an investment would have grown (or shrunk) over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes! Understanding cumulative returns helps investors identify consistently high-performing stocks for long-term wealth generation. Businesses can also assess whether strategic decisions correlate with positive returns, fine-tuning future strategies.

# %% [markdown]
# #### Chart - 16

# %%
# Chart - 16 visualization code 

plt.figure(figsize=(12, 6))
plt.bar(df['date'], df['open'], color='orange') 
plt.title('Opening Price Over Time')
plt.xlabel('Date')
plt.ylabel('Opening Price')
step = max(1, len(df['date']) // 10)
plt.xticks(df['date'][::step], rotation=45, ha='right')
plt.tight_layout() 
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was chosen to visualize the trading volume over time, as volume indicates market activity and investor interest. Tracking volume helps understand periods of high and low market participation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows fluctuations in trading volume, with distinct peaks and valleys. High volume spikes often align with major market events or significant price movements, while low volume may signal market indecision or lack of interest.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding high price trends helps time market entries and exits for maximum profit. By identifying growth periods, I can capitalize on rising markets, while recognizing stability phases aids in long-term planning.

# %% [markdown]
# #### Chart - 17

# %%
# Chart - 17 visualization code (Fixed)

plt.figure(figsize=(12, 6))
plt.hist(df['close'], bins=30, color='red', edgecolor='black')  # Histogram of closing prices
plt.title('Distribution of Closing Prices')
plt.xlabel('Closing Price')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The closing price is essential for financial analysis, so I chose a line chart to show the closing price trend over time. It provides a clear view of how prices settle at the end of each trading period, reflecting investor sentiment and market performance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows significant growth phases and eventual stabilization. Steady upward trends indicate positive market performance, while short-term volatility highlights periods of market correction or investor uncertainty.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, tracking closing prices helps make data-driven decisions. Consistent price growth signals a healthy market, encouraging investment, while recognizing patterns allows for better risk management.

# %% [markdown]
# #### Chart - 18

# %%
# Chart - 18 visualization code (Fixed)

plt.figure(figsize=(12, 6))
plt.scatter(df['low'], df['high'], color='green', alpha=0.5)  # Swapped 'volume' for 'low'
plt.title('Low Price vs High Price')
plt.xlabel('Low Price')
plt.ylabel('High Price')
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart to show trading volume because it visualizes activity intensity. High volumes suggest market interest, while low volumes indicate quiet periods.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows volume spikes aligning with price movements, suggesting strong investor engagement during key events. Sustained high volumes often precede price shifts, serving as a predictive indicator.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, volume analysis helps predict market movements and adjust strategies. High volumes during price surges signal strong market confidence, guiding better timing for trades or investment decisions.

# %% [markdown]
# #### Chart - 19

# %%
# Chart - 19 visualization code 

plt.figure(figsize=(12, 6))
plt.plot(df['date'], df['low'], color='brown')  
plt.title('Low Price Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Low Price')
step = max(1, len(df['date']) // 10)  # Show every 10th date
plt.xticks(df['date'][::step], rotation=45, ha='right')
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The opening price sets the market tone, so I used a line chart to show opening price changes. It helps understand initial market reactions and anticipate day-long trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows gradual price increases, reflecting positive market sentiment. Occasional gaps between opening and closing prices signal market volatility or overnight sentiment shifts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, tracking opening prices helps forecast market direction. Recognizing consistent upward openings supports bullish strategies, while identifying gaps informs risk management.

# %% [markdown]
# #### Chart - 20

# %%
# Chart - 20 visualization code 

plt.figure(figsize=(12, 6))
plt.bar(df['date'], df['high'], color='cyan') 
plt.title('High Price Over Time')
plt.xlabel('Date')
plt.ylabel('High Price')
step = max(1, len(df['date']) // 10) 
plt.xticks(df['date'][::step], rotation=45, ha='right')
plt.tight_layout() 
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart to visualize price ranges, as it highlights market volatility. Larger ranges show higher uncertainty, while smaller ranges suggest market stability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals expanding and contracting ranges, reflecting varying volatility. Periods of large ranges often coincide with market news or external shocks, while stable ranges indicate calm markets.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding price ranges helps manage risk and optimize trade timing. High volatility periods offer profit opportunities, while stable ranges support steady growth strategies.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# **Solution to Business Objective**
#
# Based on the insights derived from the charts, I have crafted a strategic plan that can help the client achieve their business objectives. Let’s break it down step by step, leveraging each data point to drive growth, enhance decision-making, and strengthen market positioning.
#
# ---
#
# ### 1. **Optimizing Market Timing and Pricing Strategies**
#
# The analysis of high and low prices over time reveals valuable patterns of price fluctuations, surges, and stabilization periods. By monitoring these trends, the client can:
# - **Identify the Best Entry and Exit Points:** Capitalize on price spikes by timing product launches, promotions, or market entries during rising price phases to maximize revenue.
# - **Dynamic Pricing Strategy:** Use historical high and low price data to implement a flexible pricing model. For instance, during periods of high volatility, introducing promotional discounts or bundled offers can attract price-sensitive customers while still preserving profit margins.
#
# **Actionable Steps:**
# - Continuously monitor price movements to anticipate market shifts.
# - Use predictive analytics to forecast future price trends.
# - Set price alerts to automate decision-making for optimal timing.
#
# ---
#
# ### 2. **Leveraging Closing Price Trends for Investment Decisions**
#
# Closing prices reflect market sentiment and overall performance. Understanding these trends empowers the client to:
# - **Make Informed Investment Choices:** A steady upward closing price trend indicates market strength, signaling safe periods for reinvesting profits or expanding business operations.
# - **Risk Management:** Recognizing stabilization after volatility helps in mitigating risks. The client can allocate resources more confidently during stable periods and exercise caution during sharp swings.
#
# **Actionable Steps:**
# - Build a decision matrix based on closing price patterns.
# - Use statistical models to quantify price stability.
#
# ---
#
# ### 3. **Maximizing Opportunities Through Trading Volume Analysis**
#
# Trading volume is a direct indicator of market activity. High volumes often align with significant price movements, revealing moments of heightened investor interest. The client can use this to:
# - **Identify Market Momentum:** High volume during a price surge signals strong market confidence, presenting an opportunity to ride bullish trends.
# - **Optimize Marketing Efforts:** Align marketing campaigns with periods of high trading activity to amplify visibility and sales.
#
# **Actionable Steps:**
# - Set volume thresholds to signal potential buying or selling opportunities.
# - Combine volume analysis with price trends for stronger predictions.
#
# ---
#
# ### 4. **Using Opening Prices to Forecast Market Sentiment**
#
# The opening price sets the initial tone for the trading day. By tracking this metric, the client can:
# - **Plan Day-to-Day Operations:** If opening prices show consistent upward movement, it suggests positive sentiment, allowing the client to take more aggressive sales or promotional actions.
# - **Anticipate Volatility:** Gaps between opening and closing prices can hint at overnight sentiment shifts, helping the client brace for potential volatility.
#
# **Actionable Steps:**
# - Use early-morning market data to adapt daily strategies.
# - Develop contingency plans for sudden price gaps.
#
# ---
#
# ### 5. **Managing Risk with Price Range Insights**
#
# The high-low price range over time is a key indicator of volatility. Understanding this can help the client:
# - **Balance Risk and Reward:** Wider ranges indicate more uncertainty but also greater potential returns. The client can strategically decide whether to pursue high-reward opportunities or prioritize stability.
# - **Portfolio Diversification:** During periods of high volatility, diversifying product offerings or market segments can hedge risks and stabilize revenue streams.
#
# **Actionable Steps:**
# - Set risk tolerance levels based on range data.
# - Use historical volatility to model future scenarios.
#
# ---
#
# ### 6. **Integrating Data-Driven Decision-Making**
#
# To fully harness these insights, the client should implement a data-driven decision-making framework. This involves:
# - **Real-Time Dashboards:** Use tools like Power BI to visualize live data and make quick adjustments.
# - **Predictive Analytics:** Use machine learning models to forecast future market behaviors based on historical data.
# - **Continuous Learning:** Regularly review and refine strategies as new data emerges.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **Final Conclusion: Unlocking Business Growth Through Data-Driven Insights**
#
# The analysis of charts depicting key market metrics — including high prices, closing prices, trading volumes, opening prices, and price ranges over time — has provided invaluable insights that can drive strategic business decisions. By interpreting these visualizations, I can confidently outline a comprehensive path toward business growth, risk management, and optimized market positioning.
#
# **Leveraging Price Trends for Strategic Decision-Making:**
#
# The high price and closing price trends revealed critical information about market sentiment and performance. Steady price growth and periodic spikes indicate moments of opportunity where businesses can strategically enter or exit the market for maximum profit. For example, recognizing periods of sustained high prices allows companies to capitalize on bullish trends, while identifying price stabilizations supports long-term planning and conservative investment strategies.
#
# **Trading Volume as a Market Sentiment Indicator:**
#
# The analysis of trading volume over time showed clear correlations with price movements, acting as a reliable indicator of investor interest. High trading volumes during price surges suggest strong market confidence, signaling ideal moments for businesses to make key decisions, such as launching products or adjusting marketing strategies to align with heightened interest. Understanding volume patterns also helps predict potential price shifts, giving businesses a proactive edge.
#
# **Opening Prices and Market Sentiment:**
#
# The opening price data provided insights into initial market reactions and investor sentiment. Gradual increases in opening prices indicated positive market outlooks, while occasional gaps between opening and closing prices highlighted volatility. Businesses can use this information to forecast short-term market trends, aligning sales strategies or promotional activities with anticipated market conditions to maximize revenue opportunities.
#
# **Managing Risk Through Price Range Analysis:**
#
# Visualizing the high-low price range over time illuminated periods of market volatility versus stability. Large price ranges signaled high uncertainty but also potential profit opportunities for businesses willing to take calculated risks. Conversely, smaller, stable price ranges suggested calmer market conditions, ideal for steady, incremental growth. This insight enables businesses to fine-tune risk management strategies, balancing aggressive growth tactics with periods of stability.
#
# **Holistic Impact on Business Strategy:**
#
# Together, these insights empower businesses to create well-rounded strategies. By timing market entries based on price trends, adjusting investment decisions according to trading volume, and managing risk through price range analysis, companies can optimize their market presence. This data-driven approach not only enhances decision-making but also builds resilience against market uncertainties, fostering sustainable growth.
#
# In conclusion, these chart-driven insights form the foundation of a powerful business strategy. By leveraging historical data to anticipate future trends, businesses can confidently navigate market dynamics, seize growth opportunities, and build a competitive edge. Through continuous data monitoring and adaptive decision-making, they can transform insights into impactful actions, unlocking long-term success and financial prosperity.
